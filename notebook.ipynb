# %%
# !pip install "pint==0.25"
# !pip install -i https://test.pypi.org/simple/ kinematicsbw==0.3.1
# Out:
# ...
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
import pint
import kinematicsbw as km
print(km.calculate_current_velocity(3,3,3))
# Out:
# 12.0 meter / second
