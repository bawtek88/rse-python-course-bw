# %%
# !pip install "pint==0.25"
# !pip install -i https://test.pypi.org/simple/ kinematicsbw==0.4.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.5/305.5 kB 12.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
import pint
import kinematicsbw as kbw

si = kbw._si
print(kbw.calculate_current_velocity(3*si.m / si.s,3,3*si.s))
# Out:
# 12.0 meter / second
